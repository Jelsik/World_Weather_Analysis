# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
city = ""
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 734

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from weatherconfig import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City" : city.title(),
                         "Lat" : city_lat,
                          "Lng" : city_lng,
                           "Max Temp" : city_max_temp,
                           "Humidity" : city_humidity,
                            "Wind" : city_wind,
                             "Cloudiness" : city_clouds,
                             "Country" : city_country,
                             "Weather Description" : city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | shache
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | concepcion
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | sao miguel do araguaia
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | poum
# Processing Record 12 of Set 1 | itarema
# Processing Record 13 of Set 1 | husavik
# Processing Record 14 of Set 1 | san patricio
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | vyazma
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | gualaquiza
# Processing Record 19 of Set 1 | yokadouma
# Processing Record 20 of Set 1 | portland
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | raudeberg
# Processing Record 24 of Set 1 | thessalon
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | henties bay
# Processing Record 29 of Set 1 | gornopravdinsk
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | la suiza
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | lavrentiya
# Processing Record 38 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | zeya
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | finschhafen
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | manggar
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | aykhal
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | cidreira
# Processing Record 3 of Set 2 | klaksvik
# Processing Record 4 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | hamilton
# Processing Record 7 of Set 2 | jackson
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | awjilah
# Processing Record 12 of Set 2 | santa maria
# Processing Record 13 of Set 2 | bilibino
# Processing Record 14 of Set 2 | myitkyina
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | martano
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | kruisfontein
# Processing Record 21 of Set 2 | kropotkin
# Processing Record 22 of Set 2 | tual
# Processing Record 23 of Set 2 | leh
# Processing Record 24 of Set 2 | port-gentil
# Processing Record 25 of Set 2 | havre-saint-pierre
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | tromso
# Processing Record 31 of Set 2 | altay
# Processing Record 32 of Set 2 | kavaratti
# Processing Record 33 of Set 2 | nuuk
# Processing Record 34 of Set 2 | palmer
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | comodoro rivadavia
# Processing Record 37 of Set 2 | gisborne
# Processing Record 38 of Set 2 | grande prairie
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | puro
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | sur
# Processing Record 43 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | kartaly
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | orgun
# City not found. Skipping...
# Processing Record 49 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 2 | leningradskiy
# Processing Record 1 of Set 3 | waipawa
# Processing Record 2 of Set 3 | rio grande
# Processing Record 3 of Set 3 | vilyuysk
# Processing Record 4 of Set 3 | barreirinhas
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | padang
# Processing Record 7 of Set 3 | suez
# Processing Record 8 of Set 3 | maniwaki
# Processing Record 9 of Set 3 | egvekinot
# Processing Record 10 of Set 3 | hare bay
# Processing Record 11 of Set 3 | elizabeth city
# Processing Record 12 of Set 3 | surab
# Processing Record 13 of Set 3 | francisco sa
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | cascas
# Processing Record 16 of Set 3 | hambantota
# Processing Record 17 of Set 3 | komsomolskiy
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | praia da vitoria
# Processing Record 22 of Set 3 | emirdag
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | kandi
# Processing Record 25 of Set 3 | samarai
# Processing Record 26 of Set 3 | phuket
# Processing Record 27 of Set 3 | maraa
# Processing Record 28 of Set 3 | bambous virieux
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | ndende
# Processing Record 32 of Set 3 | narsaq
# Processing Record 33 of Set 3 | vardo
# Processing Record 34 of Set 3 | ocos
# Processing Record 35 of Set 3 | iskateley
# Processing Record 36 of Set 3 | flinders
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | hervey bay
# Processing Record 39 of Set 3 | vicuna
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | cape town
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | kavieng
# Processing Record 45 of Set 3 | san jeronimo
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | novyy rogachik
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | pontes e lacerda
# Processing Record 50 of Set 3 | kinablangan
# Processing Record 1 of Set 4 | vidalia
# Processing Record 2 of Set 4 | fairbanks
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | quesnel
# Processing Record 5 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | teluk intan
# Processing Record 8 of Set 4 | muros
# Processing Record 9 of Set 4 | nishihara
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | ugoofaaru
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | sumbe
# Processing Record 14 of Set 4 | port hedland
# Processing Record 15 of Set 4 | shubarshi
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | alyangula
# Processing Record 18 of Set 4 | college
# Processing Record 19 of Set 4 | naidas
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | port lavaca
# Processing Record 22 of Set 4 | mandalgovi
# Processing Record 23 of Set 4 | north bend
# Processing Record 24 of Set 4 | olinda
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | zharkent
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | takoradi
# Processing Record 31 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 4 | baykit
# Processing Record 33 of Set 4 | cortez
# Processing Record 34 of Set 4 | saryozek
# Processing Record 35 of Set 4 | kut chap
# Processing Record 36 of Set 4 | karratha
# Processing Record 37 of Set 4 | ribeira grande
# Processing Record 38 of Set 4 | svetlaya
# Processing Record 39 of Set 4 | waitara
# Processing Record 40 of Set 4 | pind dadan khan
# Processing Record 41 of Set 4 | upata
# Processing Record 42 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 4 | castro
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | mao
# Processing Record 46 of Set 4 | bilma
# Processing Record 47 of Set 4 | pokanayevka
# City not found. Skipping...
# Processing Record 48 of Set 4 | hami
# Processing Record 49 of Set 4 | barra patuca
# Processing Record 50 of Set 4 | nkhotakota
# Processing Record 1 of Set 5 | misratah
# Processing Record 2 of Set 5 | grand forks
# Processing Record 3 of Set 5 | tocache
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | dungarpur
# Processing Record 6 of Set 5 | sisimiut
# Processing Record 7 of Set 5 | dhidhdhoo
# Processing Record 8 of Set 5 | taltal
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | emba
# Processing Record 11 of Set 5 | dunedin
# Processing Record 12 of Set 5 | gusau
# Processing Record 13 of Set 5 | port lincoln
# Processing Record 14 of Set 5 | heihe
# Processing Record 15 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 5 | seymchan
# Processing Record 17 of Set 5 | debre tabor
# Processing Record 18 of Set 5 | evensk
# Processing Record 19 of Set 5 | ostersund
# Processing Record 20 of Set 5 | road town
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 5 | the valley
# Processing Record 24 of Set 5 | bratsk
# Processing Record 25 of Set 5 | kidal
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | yar-sale
# Processing Record 29 of Set 5 | les cayes
# Processing Record 30 of Set 5 | beringovskiy
# Processing Record 31 of Set 5 | avarua
# Processing Record 32 of Set 5 | fereydun kenar
# Processing Record 33 of Set 5 | zaranj
# Processing Record 34 of Set 5 | anadyr
# Processing Record 35 of Set 5 | longyearbyen
# Processing Record 36 of Set 5 | turayf
# Processing Record 37 of Set 5 | saurimo
# Processing Record 38 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 5 | christchurch
# Processing Record 40 of Set 5 | xucheng
# Processing Record 41 of Set 5 | mehamn
# Processing Record 42 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 5 | obo
# Processing Record 44 of Set 5 | noumea
# Processing Record 45 of Set 5 | maumere
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | ambon
# Processing Record 48 of Set 5 | bonavista
# Processing Record 49 of Set 5 | sistranda
# Processing Record 50 of Set 5 | pisco
# Processing Record 1 of Set 6 | oranjemund
# Processing Record 2 of Set 6 | iralaya
# Processing Record 3 of Set 6 | constitucion
# Processing Record 4 of Set 6 | puerto pinasco
# City not found. Skipping...
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | lasa
# Processing Record 7 of Set 6 | tiznit
# Processing Record 8 of Set 6 | auki
# Processing Record 9 of Set 6 | broome
# Processing Record 10 of Set 6 | aksarka
# Processing Record 11 of Set 6 | port blair
# Processing Record 12 of Set 6 | perbaungan
# Processing Record 13 of Set 6 | zhuanghe
# Processing Record 14 of Set 6 | manali
# Processing Record 15 of Set 6 | uray
# Processing Record 16 of Set 6 | udachnyy
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | manutuke
# Processing Record 19 of Set 6 | himora
# City not found. Skipping...
# Processing Record 20 of Set 6 | hay river
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | fayaoue
# Processing Record 23 of Set 6 | sindor
# Processing Record 24 of Set 6 | coxim
# Processing Record 25 of Set 6 | zhangjiakou
# Processing Record 26 of Set 6 | burnie
# Processing Record 27 of Set 6 | rio gallegos
# Processing Record 28 of Set 6 | harper
# Processing Record 29 of Set 6 | kenitra
# Processing Record 30 of Set 6 | saint-raymond
# Processing Record 31 of Set 6 | taree
# Processing Record 32 of Set 6 | punta alta
# Processing Record 33 of Set 6 | upernavik
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 6 | shakiso
# Processing Record 37 of Set 6 | baie-comeau
# Processing Record 38 of Set 6 | seoul
# Processing Record 39 of Set 6 | tolaga bay
# Processing Record 40 of Set 6 | bhusawal
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | cap malheureux
# Processing Record 43 of Set 6 | dikson
# Processing Record 44 of Set 6 | libertador general san martin
# Processing Record 45 of Set 6 | aksay
# Processing Record 46 of Set 6 | ponta do sol
# Processing Record 47 of Set 6 | roma
# Processing Record 48 of Set 6 | la rioja
# Processing Record 49 of Set 6 | lvov
# Processing Record 50 of Set 6 | jaciara
# Processing Record 1 of Set 7 | faanui
# Processing Record 2 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 7 | alekseyevsk
# Processing Record 5 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 6 of Set 7 | nahawan
# Processing Record 7 of Set 7 | boende
# Processing Record 8 of Set 7 | tymovskoye
# Processing Record 9 of Set 7 | ancud
# Processing Record 10 of Set 7 | marawi
# Processing Record 11 of Set 7 | storforshei
# Processing Record 12 of Set 7 | meulaboh
# Processing Record 13 of Set 7 | sarakhs
# Processing Record 14 of Set 7 | naze
# Processing Record 15 of Set 7 | diffa
# Processing Record 16 of Set 7 | el dorado
# Processing Record 17 of Set 7 | hermosillo
# Processing Record 18 of Set 7 | ust-tsilma
# Processing Record 19 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | iqaluit
# Processing Record 22 of Set 7 | kaitangata
# Processing Record 23 of Set 7 | hofn
# Processing Record 24 of Set 7 | ahuimanu
# Processing Record 25 of Set 7 | kjopsvik
# Processing Record 26 of Set 7 | esso
# Processing Record 27 of Set 7 | chemin grenier
# Processing Record 28 of Set 7 | bolshaya atnya
# City not found. Skipping...
# Processing Record 29 of Set 7 | kjollefjord
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | kousseri
# Processing Record 32 of Set 7 | saldanha
# Processing Record 33 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 7 | marsh harbour
# Processing Record 35 of Set 7 | velsk
# Processing Record 36 of Set 7 | antalaha
# Processing Record 37 of Set 7 | tosya
# Processing Record 38 of Set 7 | dalvik
# Processing Record 39 of Set 7 | vila franca do campo
# Processing Record 40 of Set 7 | port-cartier
# Processing Record 41 of Set 7 | mahibadhoo
# Processing Record 42 of Set 7 | daru
# Processing Record 43 of Set 7 | filadelfia
# Processing Record 44 of Set 7 | khuzhir
# Processing Record 45 of Set 7 | dubbo
# Processing Record 46 of Set 7 | huarmey
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | ipixuna
# Processing Record 49 of Set 7 | yerbogachen
# Processing Record 50 of Set 7 | sauda
# Processing Record 1 of Set 8 | jabinyanah
# Processing Record 2 of Set 8 | sao felix do xingu
# Processing Record 3 of Set 8 | marystown
# Processing Record 4 of Set 8 | shitanjing
# Processing Record 5 of Set 8 | acapulco
# Processing Record 6 of Set 8 | flin flon
# Processing Record 7 of Set 8 | boyolangu
# Processing Record 8 of Set 8 | anthia
# City not found. Skipping...
# Processing Record 9 of Set 8 | skalat
# Processing Record 10 of Set 8 | grand-santi
# Processing Record 11 of Set 8 | angoche
# Processing Record 12 of Set 8 | verlaine
# Processing Record 13 of Set 8 | tateyama
# Processing Record 14 of Set 8 | grand island
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | butaritari
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | kolondieba
# Processing Record 19 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 8 | mutare
# Processing Record 21 of Set 8 | qaqortoq
# Processing Record 22 of Set 8 | hirara
# Processing Record 23 of Set 8 | cabedelo
# Processing Record 24 of Set 8 | banyo
# Processing Record 25 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 26 of Set 8 | novaya lyalya
# Processing Record 27 of Set 8 | sitka
# Processing Record 28 of Set 8 | chapais
# Processing Record 29 of Set 8 | abalak
# Processing Record 30 of Set 8 | neyyattinkara
# Processing Record 31 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 32 of Set 8 | grindavik
# Processing Record 33 of Set 8 | dustlik
# Processing Record 34 of Set 8 | bridlington
# Processing Record 35 of Set 8 | sorong
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | tirumakudal narsipur
# Processing Record 38 of Set 8 | balabac
# Processing Record 39 of Set 8 | baruun-urt
# Processing Record 40 of Set 8 | okha
# Processing Record 41 of Set 8 | sfantu gheorghe
# Processing Record 42 of Set 8 | sale
# Processing Record 43 of Set 8 | kieta
# Processing Record 44 of Set 8 | colares
# Processing Record 45 of Set 8 | wa
# City not found. Skipping...
# Processing Record 46 of Set 8 | kangaatsiaq
# Processing Record 47 of Set 8 | zelenogorskiy
# Processing Record 48 of Set 8 | porto novo
# Processing Record 49 of Set 8 | maine-soroa
# Processing Record 50 of Set 8 | jawhar
# Processing Record 1 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 9 | burlington
# Processing Record 4 of Set 9 | skogn
# Processing Record 5 of Set 9 | stephenville
# Processing Record 6 of Set 9 | llanes
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | canico
# Processing Record 9 of Set 9 | khash
# Processing Record 10 of Set 9 | mweka
# Processing Record 11 of Set 9 | zhigansk
# Processing Record 12 of Set 9 | vilhena
# Processing Record 13 of Set 9 | zhuravky
# Processing Record 14 of Set 9 | cubara
# Processing Record 15 of Set 9 | teya
# Processing Record 16 of Set 9 | coihaique
# Processing Record 17 of Set 9 | natchez
# Processing Record 18 of Set 9 | fort nelson
# Processing Record 19 of Set 9 | kahului
# Processing Record 20 of Set 9 | gallup
# Processing Record 21 of Set 9 | konya
# Processing Record 22 of Set 9 | brookhaven
# Processing Record 23 of Set 9 | porto belo
# Processing Record 24 of Set 9 | bijawar
# Processing Record 25 of Set 9 | tiarei
# Processing Record 26 of Set 9 | buala
# Processing Record 27 of Set 9 | safford
# Processing Record 28 of Set 9 | kalengwa
# Processing Record 29 of Set 9 | kachug
# Processing Record 30 of Set 9 | diamantina
# Processing Record 31 of Set 9 | ambilobe
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | cayenne
# Processing Record 34 of Set 9 | gainesville
# Processing Record 35 of Set 9 | chesma
# Processing Record 36 of Set 9 | shubarkuduk
# Processing Record 37 of Set 9 | bodoco
# City not found. Skipping...
# Processing Record 38 of Set 9 | yangambi
# Processing Record 39 of Set 9 | bull savanna
# Processing Record 40 of Set 9 | karaton
# Processing Record 41 of Set 9 | eyl
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | vostok
# Processing Record 44 of Set 9 | yarada
# Processing Record 45 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 9 | isla mujeres
# Processing Record 47 of Set 9 | maun
# Processing Record 48 of Set 9 | puebloviejo
# Processing Record 49 of Set 9 | chicama
# Processing Record 50 of Set 9 | letpadan
# Processing Record 1 of Set 10 | northam
# Processing Record 2 of Set 10 | cururupu
# Processing Record 3 of Set 10 | goderich
# Processing Record 4 of Set 10 | la celia
# Processing Record 5 of Set 10 | havelock
# Processing Record 6 of Set 10 | lethem
# Processing Record 7 of Set 10 | salinopolis
# Processing Record 8 of Set 10 | makakilo city
# Processing Record 9 of Set 10 | tungor
# Processing Record 10 of Set 10 | urusha
# Processing Record 11 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 10 | novichikha
# Processing Record 13 of Set 10 | tabalosos
# Processing Record 14 of Set 10 | kushiro
# Processing Record 15 of Set 10 | san jose
# Processing Record 16 of Set 10 | sabang
# Processing Record 17 of Set 10 | voyinka
# Processing Record 18 of Set 10 | vynohradivka
# Processing Record 19 of Set 10 | te anau
# Processing Record 20 of Set 10 | zmeinogorsk
# Processing Record 21 of Set 10 | zaykovo
# Processing Record 22 of Set 10 | anshun
# Processing Record 23 of Set 10 | limon
# Processing Record 24 of Set 10 | ormara
# Processing Record 25 of Set 10 | aripuana
# Processing Record 26 of Set 10 | berlevag
# Processing Record 27 of Set 10 | kalabo
# Processing Record 28 of Set 10 | pochutla
# Processing Record 29 of Set 10 | brae
# Processing Record 30 of Set 10 | liverpool
# Processing Record 31 of Set 10 | plouzane
# Processing Record 32 of Set 10 | mwense
# Processing Record 33 of Set 10 | kabo
# Processing Record 34 of Set 10 | tigil
# Processing Record 35 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 10 | krasnoselkup
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | kalmunai
# Processing Record 39 of Set 10 | yurgamysh
# Processing Record 40 of Set 10 | eqbaliyeh
# Processing Record 41 of Set 10 | north myrtle beach
# Processing Record 42 of Set 10 | looc
# Processing Record 43 of Set 10 | westport
# Processing Record 44 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 45 of Set 10 | sigerfjord
# City not found. Skipping...
# Processing Record 46 of Set 10 | novovorontsovka
# Processing Record 47 of Set 10 | katobu
# Processing Record 48 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 10 | verkhnevilyuysk
# Processing Record 50 of Set 10 | montataire
# Processing Record 1 of Set 11 | paita
# Processing Record 2 of Set 11 | san cristobal
# Processing Record 3 of Set 11 | montlucon
# Processing Record 4 of Set 11 | pajan
# Processing Record 5 of Set 11 | kinsale
# Processing Record 6 of Set 11 | mount gambier
# Processing Record 7 of Set 11 | mozarlandia
# Processing Record 8 of Set 11 | son la
# Processing Record 9 of Set 11 | asau
# Processing Record 10 of Set 11 | aklavik
# Processing Record 11 of Set 11 | livingstonia
# Processing Record 12 of Set 11 | necochea
# Processing Record 13 of Set 11 | rybachiy
# Processing Record 14 of Set 11 | aasiaat
# Processing Record 15 of Set 11 | laguna
# Processing Record 16 of Set 11 | bereda
# Processing Record 17 of Set 11 | lavumisa
# Processing Record 18 of Set 11 | vila velha
# Processing Record 19 of Set 11 | dzaoudzi
# Processing Record 20 of Set 11 | jalingo
# Processing Record 21 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 22 of Set 11 | feicheng
# Processing Record 23 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 24 of Set 11 | axim
# Processing Record 25 of Set 11 | mahanoro
# Processing Record 26 of Set 11 | mayo
# Processing Record 27 of Set 11 | cheremukhovo
# Processing Record 28 of Set 11 | okato
# Processing Record 29 of Set 11 | aksu
# Processing Record 30 of Set 11 | uk
# City not found. Skipping...
# Processing Record 31 of Set 11 | sioux lookout
# Processing Record 32 of Set 11 | pangkalanbuun
# Processing Record 33 of Set 11 | general roca
# Processing Record 34 of Set 11 | faya
# Processing Record 35 of Set 11 | derzhavinsk
# Processing Record 36 of Set 11 | najran
# Processing Record 37 of Set 11 | mecca
# Processing Record 38 of Set 11 | avera
# Processing Record 39 of Set 11 | venta
# Processing Record 40 of Set 11 | progreso
# Processing Record 41 of Set 11 | russell
# Processing Record 42 of Set 11 | ambovombe
# Processing Record 43 of Set 11 | celestun
# Processing Record 44 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 11 | taoudenni
# Processing Record 46 of Set 11 | zyryanka
# Processing Record 47 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 48 of Set 11 | ratnagiri
# Processing Record 49 of Set 11 | zaraza
# Processing Record 50 of Set 11 | koulamoutou
# Processing Record 1 of Set 12 | ulaanbaatar
# Processing Record 2 of Set 12 | sola
# Processing Record 3 of Set 12 | qostanay
# Processing Record 4 of Set 12 | lake city
# Processing Record 5 of Set 12 | heishan
# Processing Record 6 of Set 12 | tezu
# Processing Record 7 of Set 12 | kamenka
# Processing Record 8 of Set 12 | puerto del rosario
# Processing Record 9 of Set 12 | two hills
# Processing Record 10 of Set 12 | kholodnyy
# Processing Record 11 of Set 12 | storslett
# Processing Record 12 of Set 12 | grand gaube
# Processing Record 13 of Set 12 | chadiza
# Processing Record 14 of Set 12 | jumla
# Processing Record 15 of Set 12 | tyret pervaya
# Processing Record 16 of Set 12 | gonyu
# City not found. Skipping...
# Processing Record 17 of Set 12 | yelan-koleno
# Processing Record 18 of Set 12 | zvishavane
# Processing Record 19 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 20 of Set 12 | sungaipenuh
# Processing Record 21 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 12 | channel-port aux basques
# Processing Record 23 of Set 12 | dum duma
# Processing Record 24 of Set 12 | tutoia
# Processing Record 25 of Set 12 | adana
# Processing Record 26 of Set 12 | melfi
# Processing Record 27 of Set 12 | ati
# Processing Record 28 of Set 12 | poykovskiy
# Processing Record 29 of Set 12 | lahij
# Processing Record 30 of Set 12 | buraydah
# Processing Record 31 of Set 12 | solnechnyy
# Processing Record 32 of Set 12 | juneau
# Processing Record 33 of Set 12 | sosnovo-ozerskoye
# Processing Record 34 of Set 12 | vao
# Processing Record 35 of Set 12 | tecpan
# Processing Record 36 of Set 12 | linxia
# Processing Record 37 of Set 12 | muisne
# Processing Record 38 of Set 12 | fort saint james
# Processing Record 39 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 12 | morondava
# Processing Record 41 of Set 12 | sinnamary
# Processing Record 42 of Set 12 | camacha
# Processing Record 43 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 12 | paamiut
# Processing Record 45 of Set 12 | manassas
# Processing Record 46 of Set 12 | dourdan
# Processing Record 47 of Set 12 | jimma
# Processing Record 48 of Set 12 | chengde
# Processing Record 49 of Set 12 | hachioji
# Processing Record 50 of Set 12 | marsa matruh
# Processing Record 1 of Set 13 | khandbari
# Processing Record 2 of Set 13 | monrovia
# Processing Record 3 of Set 13 | severo-kurilsk
# Processing Record 4 of Set 13 | oranjestad
# Processing Record 5 of Set 13 | marquette
# Processing Record 6 of Set 13 | kenora
# Processing Record 7 of Set 13 | neuquen
# Processing Record 8 of Set 13 | wuda
# Processing Record 9 of Set 13 | coulommiers
# Processing Record 10 of Set 13 | strezhevoy
# Processing Record 11 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 12 of Set 13 | nova odesa
# Processing Record 13 of Set 13 | ozinki
# Processing Record 14 of Set 13 | mantua
# Processing Record 15 of Set 13 | bandarbeyla
# Processing Record 16 of Set 13 | jalu
# Processing Record 17 of Set 13 | khani
# Processing Record 18 of Set 13 | kudahuvadhoo
# Processing Record 19 of Set 13 | capinzal
# Processing Record 20 of Set 13 | rocha
# Processing Record 21 of Set 13 | yanam
# Processing Record 22 of Set 13 | maldonado
# Processing Record 23 of Set 13 | voh
# Processing Record 24 of Set 13 | paralimni
# Processing Record 25 of Set 13 | port macquarie
# Processing Record 26 of Set 13 | patacamaya
# Processing Record 27 of Set 13 | urubicha
# Processing Record 28 of Set 13 | pitea
# Processing Record 29 of Set 13 | banjar
# Processing Record 30 of Set 13 | pudozh
# Processing Record 31 of Set 13 | weligama
# Processing Record 32 of Set 13 | merauke
# Processing Record 33 of Set 13 | luhyny
# Processing Record 34 of Set 13 | dongsheng
# Processing Record 35 of Set 13 | ajaccio
# Processing Record 36 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 13 | kenai
# Processing Record 38 of Set 13 | half moon bay
# Processing Record 39 of Set 13 | olafsvik
# Processing Record 40 of Set 13 | caravelas
# Processing Record 41 of Set 13 | kutum
# Processing Record 42 of Set 13 | ilulissat
# Processing Record 43 of Set 13 | haines junction
# Processing Record 44 of Set 13 | batesville
# Processing Record 45 of Set 13 | acari
# Processing Record 46 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 13 | homer
# Processing Record 48 of Set 13 | intibuca
# Processing Record 49 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 1 of Set 14 | wanning
# Processing Record 2 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 14 | rio bueno
# Processing Record 4 of Set 14 | bhag
# Processing Record 5 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 14 | los llanos de aridane
# Processing Record 7 of Set 14 | prince rupert
# Processing Record 8 of Set 14 | ostrovnoy
# Processing Record 9 of Set 14 | srednekolymsk
# Processing Record 10 of Set 14 | itoman
# Processing Record 11 of Set 14 | casper
# Processing Record 12 of Set 14 | kautokeino
# Processing Record 13 of Set 14 | ust-maya
# Processing Record 14 of Set 14 | ballina
# Processing Record 15 of Set 14 | mairi
# Processing Record 16 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 14 | tak bai
# Processing Record 18 of Set 14 | hue
# Processing Record 19 of Set 14 | calvia
# Processing Record 20 of Set 14 | porto santo
# Processing Record 21 of Set 14 | san mateo del mar
# Processing Record 22 of Set 14 | birmitrapur
# Processing Record 23 of Set 14 | sai buri
# Processing Record 24 of Set 14 | chimbote
# Processing Record 25 of Set 14 | botou
# Processing Record 26 of Set 14 | ridgecrest
# Processing Record 27 of Set 14 | hualmay
# Processing Record 28 of Set 14 | saint anthony
# Processing Record 29 of Set 14 | tazovskiy
# Processing Record 30 of Set 14 | tayu
# Processing Record 31 of Set 14 | dzhebariki-khaya
# Processing Record 32 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 14 | ayan
# Processing Record 34 of Set 14 | mizpe ramon
# City not found. Skipping...
# Processing Record 35 of Set 14 | korla
# Processing Record 36 of Set 14 | kilindoni
# Processing Record 37 of Set 14 | zhangye
# Processing Record 38 of Set 14 | ust-kan
# Processing Record 39 of Set 14 | xapuri
# Processing Record 40 of Set 14 | bam
# Processing Record 41 of Set 14 | esterhazy
# Processing Record 42 of Set 14 | moussoro
# Processing Record 43 of Set 14 | la cruz
# Processing Record 44 of Set 14 | ketchikan
# Processing Record 45 of Set 14 | mishan
# Processing Record 46 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 14 | belyy yar
# Processing Record 48 of Set 14 | lae
# Processing Record 49 of Set 14 | jammalamadugu
# Processing Record 50 of Set 14 | rapar
# Processing Record 1 of Set 15 | san quintin
# Processing Record 2 of Set 15 | sorland
# Processing Record 3 of Set 15 | moanda
# Processing Record 4 of Set 15 | martapura
# Processing Record 5 of Set 15 | camana
# Processing Record 6 of Set 15 | rajauri
# Processing Record 7 of Set 15 | khudumelapye
# Processing Record 8 of Set 15 | moissala
# Processing Record 9 of Set 15 | quelimane
# Processing Record 10 of Set 15 | la palma
# Processing Record 11 of Set 15 | nantucket
# Processing Record 12 of Set 15 | hamada
# Processing Record 13 of Set 15 | tautira
# Processing Record 14 of Set 15 | quatre cocos
# Processing Record 15 of Set 15 | santa barbara
# Processing Record 16 of Set 15 | galle
# Processing Record 17 of Set 15 | salvador
# Processing Record 18 of Set 15 | keshan
# City not found. Skipping...
# Processing Record 19 of Set 15 | semirom
# Processing Record 20 of Set 15 | san rafael
# Processing Record 21 of Set 15 | sayyan
# Processing Record 22 of Set 15 | diamantino
# Processing Record 23 of Set 15 | ixtapa
# Processing Record 24 of Set 15 | vanavara
# Processing Record 25 of Set 15 | a
# City not found. Skipping...
# Processing Record 26 of Set 15 | carros
# Processing Record 27 of Set 15 | matara
# Processing Record 28 of Set 15 | adrar
# Processing Record 29 of Set 15 | yuksekova
# Processing Record 30 of Set 15 | clarksdale
# Processing Record 31 of Set 15 | schruns
# Processing Record 32 of Set 15 | ternate
# Processing Record 33 of Set 15 | stekene
# Processing Record 34 of Set 15 | pokosnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 665

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                      City      Lat       Lng  Max Temp  Humidity   Wind  \
# 0                 Ushuaia -54.8000  -68.3000     35.26        87  17.27
# 1                  Shache  38.4167   77.2406     65.73        20   3.29
# 2                 Rikitea -23.1203 -134.9692     70.97        72  18.86
# 3              Concepcion -36.8270  -73.0498     51.60        82   6.91
# 4            Puerto Ayora  -0.7393  -90.3518     66.90        81   9.57
# 5                Hermanus -34.4187   19.2345     61.75        79   9.44
# 6  Sao Miguel Do Araguaia -13.2750  -50.1628     76.98        39   0.76
# 7                  Albany  42.6001  -73.9662     41.72        82   6.71
# 8             New Norfolk -42.7826  147.0587     60.91        55   3.00
# 9                    Poum -20.2333  164.0167     76.32        74  12.66
#
#    Cloudiness Country Weather Description
# 0          20      AR          few clouds
# 1          99      CN     overcast clouds
# 2         100      PF     overcast clouds
# 3         100      CL     overcast clouds
# 4          64      EC       broken clouds
# 5          10      ZA           clear sky
# 6           3      BR           clear sky
# 7          60      US       broken clouds
# 8           9      AU           clear sky
# 9          52      NC       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Wind', 'Cloudiness',
#        'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
newtitles = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind",  "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[newtitles]

# Display sample data
city_data_df.head(10)
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Ushuaia      AR -54.8000  -68.3000     35.26        87
# 1                  Shache      CN  38.4167   77.2406     65.73        20
# 2                 Rikitea      PF -23.1203 -134.9692     70.97        72
# 3              Concepcion      CL -36.8270  -73.0498     51.60        82
# 4            Puerto Ayora      EC  -0.7393  -90.3518     66.90        81
# 5                Hermanus      ZA -34.4187   19.2345     61.75        79
# 6  Sao Miguel Do Araguaia      BR -13.2750  -50.1628     76.98        39
# 7                  Albany      US  42.6001  -73.9662     41.72        82
# 8             New Norfolk      AU -42.7826  147.0587     60.91        55
# 9                    Poum      NC -20.2333  164.0167     76.32        74
#
#    Cloudiness   Wind Weather Description
# 0          20  17.27          few clouds
# 1          99   3.29     overcast clouds
# 2         100  18.86     overcast clouds
# 3         100   6.91     overcast clouds
# 4          64   9.57       broken clouds
# 5          10   9.44           clear sky
# 6           3   0.76           clear sky
# 7          60   6.71       broken clouds
# 8           9   3.00           clear sky
# 9          52  12.66       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind                   float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label ="City_ID")
